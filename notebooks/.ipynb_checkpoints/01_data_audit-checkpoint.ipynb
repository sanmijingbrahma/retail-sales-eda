# %% [markdown]
# # Retail Sales Data Audit
# ## Objectives
# - Do proper audit of retial dataset
# - Shape of data
# - Datatypes
# - Properties of each observation(columns)
# - Find total missing and duplicate values
# - Number of unique values for each property
# - Basic stats of numerical and categorical data
# - Preview of first and last 5 rows

# %% [markdown]
# ## Import Library and Set Up data

# %%
import pandas as pd

df = pd.read_csv("../data/raw/retail_sales_dataset.csv")

df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %% [markdown]
# ## Shape of Data

# %%
rows, cols = df.shape

print(f"Rows : {rows}")
print(f"Columns : {cols}")
# Out:
# Rows : 1000
# Columns : 9

# %% [markdown]
# - Dataset has 1000 rows or observation
# - and has 9 rows each showing properties of all observation

# %% [markdown]
# ## Columns of Dataset

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %% [markdown]
# - Columns are
#     - Transaction ID
#     - Date
#     - Customer ID
#     - Gender
#     - Age
#     - Product Category
#     - Quantity
#     - Price per Unit
#     - Total Amount

# %% [markdown]
# ## Data types of All Columns

# %%
df.dtypes
# Out:
# Transaction ID       int64
# Date                object
# Customer ID         object
# Gender              object
# Age                  int64
# Product Category    object
# Quantity             int64
# Price per Unit       int64
# Total Amount         int64
# dtype: object

# %% [markdown]
# - Here we have found out all data types of data for each columns of dataset
# - Here "Date" should be of datetime data type if we want to do time based analysis

# %% [markdown]
# ## Missing Values

# %%
df.isna().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %% [markdown]
# - As per the result we have no missing values/nan in our dataset

# %% [markdown]
# ## Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - We have also noticed that we also do not have any duplicate rows.
# - All rows are unique

# %% [markdown]
# ## Number of Unique Values of columns

# %%
df.nunique()
# Out:
# Transaction ID      1000
# Date                 345
# Customer ID         1000
# Gender                 2
# Age                   47
# Product Category       3
# Quantity               4
# Price per Unit         5
# Total Amount          18
# dtype: int64

# %% [markdown]
# ## Basic Statistics

# %% [markdown]
# ### Numerical

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %% [markdown]
# ### Categorical

# %%
df.describe(include="object")
# Out:
#               Date Customer ID  Gender Product Category
# count         1000        1000    1000             1000
# unique         345        1000       2                3
# top     2023-05-16     CUST001  Female         Clothing
# freq            11           1     510              351

# %% [markdown]
# - Here we have done Basic stats of both
#     - Numerical data
#     - Categorical data

# %% [markdown]
# ## First 5 rows

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %% [markdown]
# ## Last 5 Rows

# %%
df.tail()
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 995             996  2023-05-16     CUST996    Male   62         Clothing
# 996             997  2023-11-17     CUST997    Male   52           Beauty
# 997             998  2023-10-29     CUST998  Female   23           Beauty
# 998             999  2023-12-05     CUST999  Female   36      Electronics
# 999            1000  2023-04-12    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# 995         1              50            50
# 996         3              30            90
# 997         4              25           100
# 998         3              50           150
# 999         4              30           120

# %% [markdown]
# ##  Conclusion
# - Dataset consists of 1000 observation with 9 properties for each
# - There is no missing and duplicate values in dataset
# - We have found unique values for each columns
# - We have found out basic stats for both numerical and categorical data.
